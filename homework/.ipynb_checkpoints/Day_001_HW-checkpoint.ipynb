# %% [markdown]
# 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# https://www.kaggle.com/tmdb/tmdb-movie-metadata#tmdb_5000_movies.csv
#
# 1. 你選的這組資料為何重要：分析歷史電影，預測票房佳之電影協助片商投資
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)：The Movie Database提供，蒐集歷史上電影清單及提供觀眾評分
#
# 3. 蒐集而來的資料型態為何：國家、類型為非結構化資料；預算、評分、票房為結構化資料
#
# 4. 這組資料想解決的問題如何評估：R Squared

# %% [markdown]
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)：提升業績定義為增加載客率，透過蒐集各項變數來預測各地叫車人數
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)：必須從叫車APP上蒐集到旅客的搭乘日期時間、起訖點、天氣，或是由司機手動紀錄以上資料(如果非透過APP叫車)
#
# 3. 蒐集而來的資料型態為何：搭乘時間為結構化資料(可分為月份/星期/時段等)，起訖點可結合地圖產生熱點，天氣可化為0/1變數。
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)：R Squared

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_square_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

MSE = mean_square_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MSE))
# Out:
# The Mean absolute error is 280.281
